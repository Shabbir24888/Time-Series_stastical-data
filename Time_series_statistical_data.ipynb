# %% [markdown]
# ## Visualizing Time Series

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.cm as cm    ## cm stands for color maps
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4

# %%
address = 'E:\Jupyter notebook\Linked_in learning DS\Sales report\sales_data_sample.csv'
#df = pd.read_csv(address)
df = pd.read_csv(address, index_col='ORDERDATE',encoding='cp1252',parse_dates=True)

df.head()
# Out:
#             ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# ORDERDATE
# 2003-02-24        10107               30      95.70                2  2871.00
# 2003-05-07        10121               34      81.35                5  2765.90
# 2003-07-01        10134               41      94.74                2  3884.34
# 2003-08-25        10145               45      83.26                6  3746.70
# 2003-10-10        10159               49     100.00               14  5205.27
#
#              STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  \
# ORDERDATE                                                    ...
# 2003-02-24  Shipped       1         2     2003  Motorcycles  ...
# 2003-05-07  Shipped       2         5     2003  Motorcycles  ...
# 2003-07-01  Shipped       3         7     2003  Motorcycles  ...
# 2003-08-25  Shipped       3         8     2003  Motorcycles  ...
# 2003-10-10  Shipped       4        10     2003  Motorcycles  ...
#
# ...

# %%
Qty = df['ORDERLINENUMBER'].plot()

# %%
df2 = df.sample(n=100,random_state=25,axis=0)
plt.xlabel('Order date')
plt.ylabel('Order Quantity')
plt.title('Superstore sales')

small_qty = df2['ORDERLINENUMBER'].plot()

# %% [markdown]
# ## Statistical data graphs

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.cm as cm    ## cm stands for color maps
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 5,4

# %%
import seaborn as sb
sb.set_style('whitegrid')

address = 'E:\Jupyter notebook\Linked_in learning DS\mtcars\mtcars.csv'
cars = pd.read_csv(address)


mpg=cars['mpg']

mpg.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(mpg)
plt.plot()
# Out:
# []

# %%
sb.distplot(mpg)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %% [markdown]
# ### Scatter plot in action

# %%
cars.plot(kind='scatter',x='hp',y='mpg',c=['darkgray'],s=150)
# Out:
# <AxesSubplot:xlabel='hp', ylabel='mpg'>

# %%
## Scatter plot using seaborn
sb.regplot(x='hp',y='mpg',data=cars,scatter=True)
# Out:
# <AxesSubplot:xlabel='hp', ylabel='mpg'>

# %% [markdown]
# ### Scatter plot matrix

# %%
sb.pairplot(cars)

# %%
cars_subset = cars[['mpg','disp','hp','wt']]
sb.pairplot(cars_subset)
plt.show()

# %% [markdown]
# ### Box plot

# %%
cars.boxplot(column='mpg',by='am')
cars.boxplot(column='wt',by='am')
# Out:
# <AxesSubplot:title={'center':'wt'}, xlabel='am'>

# %%
## box plot using seaborn

sb.boxplot(x='am',y='mpg',data=cars)
# Out:
# <AxesSubplot:xlabel='am', ylabel='mpg'>
